# %%
import pandas as pd

import seaborn as sns

import matplotlib.pyplot as plt

data = pd.read_csv('kelompok-10.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 1 to 5
# Data columns (total 11 columns):
#  #   Column                                                                                                                                                                                                                                                                                                               Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                                                                                               --------------  -----
# ...

# %%
data.dtypes
# Out:
# ;"                                                                                                                                                                                                                                                                                                                     object
# Melalui internet mahasiswa dapat mengakses berbagai literatur dan referensi ilmu pengetahuan yang dibutuhkan dengan cepat sehingga dapat memudahkan proses studinya                                                                                                                                                     int64
# E-Learning dapat menjadi efektif apabila adanya kerjasama antara pengajar dan siswanya untuk mensukseskannya tanpa salah satu dari keduanya keberadaan E-Learning tidak akan berjalan secara lancar                                                                                                                     int64
# ...

# %%
data.head(5)
# Out:
#                     ;"  \
# 1        Sangat Setuju
# 2               Setuju
# 3            Ragu-Ragu
# 4         Tidak Setuju
# 5  Sangat Tidak Setuju
#
#    Melalui internet mahasiswa dapat mengakses berbagai literatur dan referensi ilmu pengetahuan yang dibutuhkan dengan cepat sehingga dapat memudahkan proses studinya  \
# 1                                                211
# 2                                                251
# 3                                                 17
# 4                                                  0
# 5                                                  9
#
#    E-Learning dapat menjadi efektif apabila adanya kerjasama antara pengajar dan siswanya untuk mensukseskannya tanpa salah satu dari keduanya keberadaan E-Learning tidak akan berjalan secara lancar  \
# 1                                                215
# 2                                                255
# 3                                                 16
# ...

# %%
data.shape
# Out:
# (5, 11)

# %%
data.columns
# Out:
# Index([';"',
#        'Melalui internet mahasiswa dapat mengakses berbagai literatur dan referensi ilmu pengetahuan yang dibutuhkan dengan cepat sehingga dapat memudahkan proses studinya',
#        'E-Learning dapat menjadi efektif apabila adanya kerjasama antara pengajar dan siswanya untuk mensukseskannya tanpa salah satu dari keduanya keberadaan E-Learning tidak akan berjalan secara lancar',
#        'Efektivitas dari E-Learning didukung oleh keahlian dan kreativitas pengajar dalam meracik materi yang akan disampaikan kepada peserta didiknya',
#        'E-Learning dengan metode pembelajaran secara formal misalnya adalah pembelajaran dengan kurikulum silabus mata pelajaran dan tes yang telah diatur dan disusun berdasarkan jadwal yang telah disepakati pihak-pihak terkait (pengelola e-Learning dan pembelajar itu sendiri) Apakah anda setuju dengan metode ini?',
# ...

# %%
#deskripsi
data.describe()
# Out:
#        Melalui internet mahasiswa dapat mengakses berbagai literatur dan referensi ilmu pengetahuan yang dibutuhkan dengan cepat sehingga dapat memudahkan proses studinya  \
# count                                           5.000000
# mean                                           97.600000
# std                                           122.742821
# min                                             0.000000
# 25%                                             9.000000
# 50%                                            17.000000
# 75%                                           211.000000
# max                                           251.000000
#
#        E-Learning dapat menjadi efektif apabila adanya kerjasama antara pengajar dan siswanya untuk mensukseskannya tanpa salah satu dari keduanya keberadaan E-Learning tidak akan berjalan secara lancar  \
# count                                           5.000000
# mean                                           98.400000
# ...

# %%
corr = data.corr()
corr
# Out:
#                                                     Melalui internet mahasiswa dapat mengakses berbagai literatur dan referensi ilmu pengetahuan yang dibutuhkan dengan cepat sehingga dapat memudahkan proses studinya  \
# Melalui internet mahasiswa dapat mengakses berb...                                           1.000000
# E-Learning dapat menjadi efektif apabila adanya...                                           0.999955
# Efektivitas dari E-Learning didukung oleh keahl...                                           0.985587
# E-Learning dengan metode pembelajaran secara fo...                                           0.836055
# E-Learning juga dilakukan secara informal denga...                                           0.901186
# Internet dengan metode belajar online memudahka...                                           0.880286
# Penggunaan E-learning untuk menunjang pelaksana...                                           0.729139
# ...

# %%
# correlation map
# higher correlations are brighter
f,ax = plt.subplots(figsize=(40,40))
sns.heatmap(corr, annot=True, linewidths=.5, fmt='.3f', ax=ax)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
